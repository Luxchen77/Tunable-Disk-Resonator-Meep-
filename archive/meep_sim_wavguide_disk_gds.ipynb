# %%
import meep as mp
import gdspy
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load GDS
gds_path = "/mnt/c/Users/ku/jonah/samplemaker-master/samplemaker-master/test_franzi_2_confused.gds"
gds_lib = gdspy.GdsLibrary()
gds_lib.read_gds(gds_path)

print("Cells in library:", list(gds_lib.cells.keys()))

# Function to collect polygons from a cell (recursively) by layer
def collect_polygons(cell, layers=(0,1)):
    polys = []
    
    # Get polygons grouped by (layer, datatype)
    polygons_by_spec = cell.get_polygons(by_spec=True)
    
    for (layer, datatype), poly_list in polygons_by_spec.items():
        if layer in layers:
            polys.extend(poly_list)
    
    # Recursively traverse references
    for ref in cell.references:
        ref_cell = gds_lib.cells[ref.ref_cell.name]
        polys.extend(collect_polygons(ref_cell, layers))
    
    return polys

# Pick a top-level cell
top_cell = list(gds_lib.cells.values())[1]

# Collect only polygons on layer 5
polygons = collect_polygons(top_cell, layers=(5,))
print(f"Collected {len(polygons)} polygons from layer 5")
# Out:
# Cells in library: ['DISKRESONATOR_0001', 'CELL00']
# Collected 4 polygons from layer 5

# %%
# Compute bounding box of polygons
all_points = np.vstack(polygons)
x_min, x_max = all_points[:,0].min(), all_points[:,0].max()
y_min, y_max = all_points[:,1].min(), all_points[:,1].max()

# Define cell with some padding
pad = 2
sx = (x_max - x_min) + 2*pad
sy = (y_max - y_min) + 2*pad
cell = mp.Vector3(sx, sy, 0)

# Shift origin so that (0,0) is cell center
x_center = 0.5*(x_min + x_max)
y_center = 0.5*(y_min + y_max)

# Rebuild geometry in centered coordinates
geometry = []
for poly in polygons:
    vertices = [mp.Vector3(x - x_center, y - y_center) for x,y in poly]
    geometry.append(mp.Prism(vertices=vertices, height=mp.inf, material=mp.Medium(epsilon=12)))

# Now place the source at physical (0,12) directly
source_x = 0- x_center
source_y = 12 - y_center
sources = [mp.Source(mp.GaussianSource(frequency=0.9881, fwidth=0.1),
                     component=mp.Ez,
                     center=mp.Vector3(source_x, source_y),
                     size=mp.Vector3(0,2,0))]

# -----------------------------
# Plot the layout and source
# -----------------------------
plt.figure(figsize=(6,6))
for poly in polygons:
    shifted_poly = poly - np.array([x_center, y_center])
    plt.plot(shifted_poly[:,0], shifted_poly[:,1], '-o', label='Polygon')
plt.plot(source_x, source_y, 'rx', markersize=10, label='Source')

plt.axis('equal')
plt.xlabel("x (µm)")
plt.ylabel("y (µm)")
plt.title("Polygons and source in simulation coordinates")
plt.show()

# %%
# ------------------------
# Simulation parameters
# ------------------------

fmin = 0.2    # minimum frequency in Meep units
fmax = 1.8    # maximum frequency
df   = fmax - fmin
nfreq = 500   # number of frequency points

# Simulation cell
pml_layers = [mp.PML(1.0)]
resolution = 11

# Broadband Gaussian source (covers fmin–fmax)
sources = [mp.Source(mp.GaussianSource(frequency=(fmin+fmax)/2, fwidth=df),
                     component=mp.Ez,
                     center=mp.Vector3(source_x, source_y),
                     size=mp.Vector3(0, 0, 0))]

sim = mp.Simulation(cell_size=cell,
                    geometry=geometry,
                    sources=sources,
                    boundary_layers=pml_layers,
                    resolution=resolution)

# ------------------------
# Flux monitors
# ------------------------

flux_x = 0
flux_y = 2

flux_region = mp.FluxRegion(center=mp.Vector3(flux_x, flux_y),
                            size=mp.Vector3(0, 0.5, 0))  # full waveguide width

# Transmission flux monitor: centered at (fmin+fmax)/2, width = df
trans_flux = sim.add_flux((fmin+fmax)/2, df, nfreq, flux_region)

# Input flux monitor (for normalization)
input_flux_region = mp.FluxRegion(center=mp.Vector3(source_x, source_y),
                                  size=mp.Vector3(0, 0, 0))
input_flux = sim.add_flux((fmin+fmax)/2, df, nfreq, input_flux_region)

# ------------------------
# Run the simulation
# ------------------------
sim.run(until_after_sources=mp.stop_when_fields_decayed(
    30, mp.Ez, mp.Vector3(flux_x, flux_y), 1e-2))

# ------------------------
# Get transmission spectrum
# ------------------------
frequencies = np.array(mp.get_flux_freqs(trans_flux))   # freq points from 0.6–1.2
transmission = np.array(mp.get_fluxes(trans_flux))

# ------------------------
# Plot
# ------------------------
plt.figure(figsize=(10,6))
plt.plot(frequencies, transmission, label="Transmission")
plt.xlabel("Frequency (1/µm)")
plt.ylabel("Transmission")
plt.title("Waveguide Transmission Spectrum")
plt.legend()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00640512 s
# Working in 2D dimensions.
# Computational cell is 44 x 18 x 0 with resolution 10
#      prism, center = (0.94981,6,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 84 vertices:
#           (20,6.982,0)
#           (19.996,6.982,0)
#           (19.996,6.195,0)
#           (17.996,6.51,0)
#           (17.581,6.51,0)
#           (17.581,6.852,0)
#           (17.647,6.982,0)
#           (17.344,6.982,0)
#           (17.411,6.852,0)
#           (17.411,6.51,0)
#           (16.996,6.51,0)
#           (14.996,6.195,0)
#           (8.33,6.195,0)
#           (6.33,6.51,0)
#           (5.915,6.51,0)
#           (5.915,6.852,0)
#           (5.981,6.982,0)
#           (5.678,6.982,0)
#           (5.745,6.852,0)
#           (5.745,6.51,0)
#           (5.33,6.51,0)
#           (3.33,6.195,0)
#           (-3.336,6.195,0)
#           (-5.336,6.51,0)
#           (-5.751,6.51,0)
#           (-5.751,6.852,0)
#           (-5.685,6.982,0)
#           (-5.988,6.982,0)
#           (-5.921,6.852,0)
#           (-5.921,6.51,0)
#           (-6.336,6.51,0)
#           (-8.336,6.195,0)
#           (-15,6.195,0)
#           (-17,6.51,0)
#           (-17.415,6.51,0)
#           (-17.415,6.852,0)
#           (-17.349,6.982,0)
#           (-17.652,6.982,0)
#           (-17.585,6.852,0)
#           (-17.585,6.51,0)
#           (-18,6.51,0)
#           (-20,6.195,0)
#           (-20,5.805,0)
#           (-18,5.49,0)
#           (-17.585,5.49,0)
#           (-17.585,5.148,0)
#           (-17.652,5.018,0)
#           (-17.349,5.018,0)
#           (-17.415,5.148,0)
#           (-17.415,5.49,0)
#           (-17,5.49,0)
#           (-15,5.805,0)
#           (-8.336,5.805,0)
#           (-6.336,5.49,0)
#           (-5.921,5.49,0)
#           (-5.921,5.148,0)
#           (-5.988,5.018,0)
#           (-5.685,5.018,0)
#           (-5.751,5.148,0)
#           (-5.751,5.49,0)
#           (-5.336,5.49,0)
#           (-3.336,5.805,0)
#           (3.33,5.805,0)
#           (5.33,5.49,0)
#           (5.745,5.49,0)
#           (5.745,5.148,0)
#           (5.678,5.018,0)
#           (5.981,5.018,0)
#           (5.915,5.148,0)
#           (5.915,5.49,0)
#           (6.33,5.49,0)
#           (8.33,5.805,0)
#           (14.996,5.805,0)
#           (16.996,5.49,0)
#           (17.411,5.49,0)
#           (17.411,5.148,0)
#           (17.344,5.018,0)
#           (17.647,5.018,0)
#           (17.581,5.148,0)
#           (17.581,5.49,0)
#           (17.996,5.49,0)
#           (19.996,5.805,0)
#           (19.996,5.018,0)
#           (20,5.018,0)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0.94981,-6,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 84 vertices:
#           (20,-5.018,0)
#           (19.996,-5.018,0)
#           (19.996,-5.805,0)
#           (17.996,-5.49,0)
#           (17.581,-5.49,0)
#           (17.581,-5.148,0)
#           (17.647,-5.018,0)
#           (17.344,-5.018,0)
#           (17.411,-5.148,0)
#           (17.411,-5.49,0)
#           (16.996,-5.49,0)
#           (14.996,-5.805,0)
#           (8.33,-5.805,0)
#           (6.33,-5.49,0)
#           (5.915,-5.49,0)
#           (5.915,-5.148,0)
#           (5.981,-5.018,0)
#           (5.678,-5.018,0)
#           (5.745,-5.148,0)
#           (5.745,-5.49,0)
#           (5.33,-5.49,0)
#           (3.33,-5.805,0)
#           (-3.336,-5.805,0)
#           (-5.336,-5.49,0)
#           (-5.751,-5.49,0)
#           (-5.751,-5.148,0)
#           (-5.685,-5.018,0)
#           (-5.988,-5.018,0)
#           (-5.921,-5.148,0)
#           (-5.921,-5.49,0)
#           (-6.336,-5.49,0)
#           (-8.336,-5.805,0)
#           (-15,-5.805,0)
#           (-17,-5.49,0)
#           (-17.415,-5.49,0)
#           (-17.415,-5.148,0)
#           (-17.349,-5.018,0)
#           (-17.652,-5.018,0)
#           (-17.585,-5.148,0)
#           (-17.585,-5.49,0)
#           (-18,-5.49,0)
#           (-20,-5.805,0)
#           (-20,-6.195,0)
#           (-18,-6.51,0)
#           (-17.585,-6.51,0)
#           (-17.585,-6.852,0)
#           (-17.652,-6.982,0)
#           (-17.349,-6.982,0)
#           (-17.415,-6.852,0)
#           (-17.415,-6.51,0)
#           (-17,-6.51,0)
#           (-15,-6.195,0)
#           (-8.336,-6.195,0)
#           (-6.336,-6.51,0)
#           (-5.921,-6.51,0)
#           (-5.921,-6.852,0)
#           (-5.988,-6.982,0)
#           (-5.685,-6.982,0)
#           (-5.751,-6.852,0)
#           (-5.751,-6.51,0)
#           (-5.336,-6.51,0)
#           (-3.336,-6.195,0)
#           (3.33,-6.195,0)
#           (5.33,-6.51,0)
#           (5.745,-6.51,0)
#           (5.745,-6.852,0)
#           (5.678,-6.982,0)
#           (5.981,-6.982,0)
#           (5.915,-6.852,0)
#           (5.915,-6.51,0)
#           (6.33,-6.51,0)
#           (8.33,-6.195,0)
#           (14.996,-6.195,0)
#           (16.996,-6.51,0)
#           (17.411,-6.51,0)
#           (17.411,-6.852,0)
#           (17.344,-6.982,0)
#           (17.647,-6.982,0)
#           (17.581,-6.852,0)
#           (17.581,-6.51,0)
#           (17.996,-6.51,0)
#           (19.996,-6.195,0)
#           (19.996,-6.982,0)
#           (20,-6.982,0)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (3.88578e-16,-1.04083e-15,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 64 vertices:
#           (3.5,-8.88178e-16,0)
#           (3.483,0.343,0)
#           (3.433,0.683,0)
#           (3.349,1.016,0)
#           (3.234,1.339,0)
#           (3.087,1.65,0)
#           (2.91,1.944,0)
#           (2.706,2.22,0)
#           (2.475,2.475,0)
#           (2.22,2.706,0)
#           (1.944,2.91,0)
#           (1.65,3.087,0)
#           (1.339,3.234,0)
#           (1.016,3.349,0)
#           (0.683,3.433,0)
#           (0.343,3.483,0)
#           (0,3.5,0)
#           (-0.343,3.483,0)
#           (-0.683,3.433,0)
#           (-1.016,3.349,0)
#           (-1.339,3.234,0)
#           (-1.65,3.087,0)
#           (-1.944,2.91,0)
#           (-2.22,2.706,0)
#           (-2.475,2.475,0)
#           (-2.706,2.22,0)
#           (-2.91,1.944,0)
#           (-3.087,1.65,0)
#           (-3.234,1.339,0)
#           (-3.349,1.016,0)
#           (-3.433,0.683,0)
#           (-3.483,0.343,0)
#           (-3.5,-8.88178e-16,0)
#           (-3.483,-0.343,0)
#           (-3.433,-0.683,0)
#           (-3.349,-1.016,0)
#           (-3.234,-1.339,0)
#           (-3.087,-1.65,0)
#           (-2.91,-1.944,0)
#           (-2.706,-2.22,0)
#           (-2.475,-2.475,0)
#           (-2.22,-2.706,0)
#           (-1.944,-2.91,0)
#           (-1.65,-3.087,0)
#           (-1.339,-3.234,0)
#           (-1.016,-3.349,0)
#           (-0.683,-3.433,0)
#           (-0.343,-3.483,0)
#           (0,-3.5,0)
#           (0.343,-3.483,0)
#           (0.683,-3.433,0)
#           (1.016,-3.349,0)
#           (1.339,-3.234,0)
#           (1.65,-3.087,0)
#           (1.944,-2.91,0)
#           (2.22,-2.706,0)
#           (2.475,-2.475,0)
#           (2.706,-2.22,0)
#           (2.91,-1.944,0)
#           (3.087,-1.65,0)
#           (3.234,-1.339,0)
#           (3.349,-1.016,0)
#           (3.433,-0.683,0)
#           (3.483,-0.343,0)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (3.88578e-16,-1.04083e-15,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 64 vertices:
#           (3.5,-8.88178e-16,0)
#           (3.483,0.343,0)
#           (3.433,0.683,0)
#           (3.349,1.016,0)
#           (3.234,1.339,0)
#           (3.087,1.65,0)
#           (2.91,1.944,0)
#           (2.706,2.22,0)
#           (2.475,2.475,0)
#           (2.22,2.706,0)
#           (1.944,2.91,0)
#           (1.65,3.087,0)
#           (1.339,3.234,0)
#           (1.016,3.349,0)
#           (0.683,3.433,0)
#           (0.343,3.483,0)
#           (0,3.5,0)
#           (-0.343,3.483,0)
#           (-0.683,3.433,0)
#           (-1.016,3.349,0)
#           (-1.339,3.234,0)
#           (-1.65,3.087,0)
#           (-1.944,2.91,0)
#           (-2.22,2.706,0)
#           (-2.475,2.475,0)
#           (-2.706,2.22,0)
#           (-2.91,1.944,0)
#           (-3.087,1.65,0)
#           (-3.234,1.339,0)
#           (-3.349,1.016,0)
#           (-3.433,0.683,0)
#           (-3.483,0.343,0)
#           (-3.5,-8.88178e-16,0)
#           (-3.483,-0.343,0)
#           (-3.433,-0.683,0)
#           (-3.349,-1.016,0)
#           (-3.234,-1.339,0)
#           (-3.087,-1.65,0)
#           (-2.91,-1.944,0)
#           (-2.706,-2.22,0)
#           (-2.475,-2.475,0)
#           (-2.22,-2.706,0)
#           (-1.944,-2.91,0)
#           (-1.65,-3.087,0)
#           (-1.339,-3.234,0)
#           (-1.016,-3.349,0)
#           (-0.683,-3.433,0)
#           (-0.343,-3.483,0)
#           (0,-3.5,0)
#           (0.343,-3.483,0)
#           (0.683,-3.433,0)
#           (1.016,-3.349,0)
#           (1.339,-3.234,0)
#           (1.65,-3.087,0)
#           (1.944,-2.91,0)
#           (2.22,-2.706,0)
#           (2.475,-2.475,0)
#           (2.706,-2.22,0)
#           (2.91,-1.944,0)
#           (3.087,-1.65,0)
#           (3.234,-1.339,0)
#           (3.349,-1.016,0)
#           (3.433,-0.683,0)
#           (3.483,-0.343,0)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 49.5324% done, 4.19292 s remaining
# subpixel-averaging is 91.5612% done, 0.378135 s remaining
# subpixel-averaging is 43.5283% done, 5.19996 s remaining
# subpixel-averaging is 82.5551% done, 0.852192 s remaining
# subpixel-averaging is 45.0293% done, 4.93764 s remaining
# subpixel-averaging is 85.5571% done, 0.69098 s remaining
# time for set_epsilon = 27.6783 s
# -----------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 47
#      42 input_flux = sim.add_flux((fmin+fmax)/2, df, nfreq, input_flux_region)
#      44 # ------------------------
#      45 # Run the simulation
#      46 # ------------------------
# ---> 47 sim.run(until_after_sources=mp.stop_when_fields_decayed(
#      48     30, mp.Ez, mp.Vector3(flux_x, flux_y), 1e-2))
#      50 # ------------------------
#      51 # Get transmission spectrum
#      52 # ------------------------
#      53 frequencies = np.array(mp.get_flux_freqs(trans_flux))   # freq points from 0.6–1.2
#
# File ~/miniforge3/envs/meep/lib/python3.9/site-packages/meep/simulation.py:4529, in Simulation.run(self, *step_funcs, **kwargs)
#    4526 if self.fields is None:
#    4527     self.init_sim()
# -> 4529 self._evaluate_dft_objects()
#    4530 self._check_material_frequencies()
#    4532 if kwargs:
#
# File ~/miniforge3/envs/meep/lib/python3.9/site-packages/meep/simulation.py:2974, in Simulation._evaluate_dft_objects(self)
#    2972 for dft in self.dft_objects:
#    2973     if dft.swigobj is None:
# -> 2974         dft.swigobj = dft.func(*dft.args)
#
# File ~/miniforge3/envs/meep/lib/python3.9/site-packages/meep/simulation.py:3501, in Simulation._add_flux(self, freq, fluxes, decimation_factor)
#    3499 if self.fields is None:
#    3500     self.init_sim()
# -> 3501 return self._add_fluxish_stuff(
#    3502     self.fields.add_dft_flux, freq, fluxes, decimation_factor
#    3503 )
#
# File ~/miniforge3/envs/meep/lib/python3.9/site-packages/meep/simulation.py:3793, in Simulation._add_fluxish_stuff(self, add_dft_stuff, freq, stufflist, decimation_factor, *args)
#    3786 v = Volume(
#    3787     center=s.center,
#    3788     size=s.size,
#    3789     dims=self.dimensions,
#    3790     is_cylindrical=self.is_cylindrical,
#    3791 )
#    3792 d0 = s.direction
# -> 3793 d = self.fields.normal_direction(v.swigobj) if d0 < 0 else d0
#    3794 c = mp.direction_component(mp.Sx, d)
#    3795 v2 = Volume(
#    3796     center=s.center,
#    3797     size=s.size,
#    3798     dims=self.dimensions,
#    3799     is_cylindrical=self.is_cylindrical,
#    3800 ).swigobj
#
# File ~/miniforge3/envs/meep/lib/python3.9/site-packages/meep/__init__.py:3295, in fields.normal_direction(self, where)
#    3294 def normal_direction(self, where):
# -> 3295     return _meep.fields_normal_direction(self, where)
#
# RuntimeError: meep: Could not determine normal direction for given grid_volume.

# %%
# ------------------------
# Get transmission spectrum
# ------------------------
frequencies = np.array(mp.get_flux_freqs(trans_flux))   # freq points from 0.6–1.2
transmission = np.array(mp.get_fluxes(trans_flux))

# Find max transmission and corresponding frequency
max_idx = np.argmax(transmission)
max_val = transmission[max_idx]
max_freq = frequencies[max_idx]

print(f"Maximum transmission: {max_val:.4f} at frequency {max_freq:.4f} (1/µm)")

# ------------------------
# Plot
# ------------------------
plt.figure(figsize=(10,6))
plt.plot(frequencies, transmission, label="Transmission")
plt.axvline(max_freq, color='red', ls='--', label=f"Max at {max_freq:.3f}")
plt.xlabel("Frequency (1/µm)")
plt.ylabel("Transmission")
plt.title("Waveguide Transmission Spectrum")
plt.legend()
plt.show()
# Out:
# Maximum transmission: 1.4568 at frequency 0.9881 (1/µm)

# %%
# -----------------------------
# Plot the layout, source, and flux monitor
# -----------------------------
plt.figure(figsize=(6,6))

# Plot polygons
for poly in polygons:
    shifted_poly = poly - np.array([x_center, y_center])
    plt.plot(shifted_poly[:,0], shifted_poly[:,1], '-o', label='Polygon')

# Plot source
plt.plot(source_x, source_y, 'rx', markersize=10, label='Source')

# Plot flux monitor
flux_x = source_x + 39  # 39 µm to the right of source
flux_y = source_y
plt.plot(flux_x, flux_y, 'gx', markersize=10, label='Flux Monitor')

plt.axis('equal')
plt.xlabel("x (µm)")
plt.ylabel("y (µm)")
plt.title("Polygons, Source, and Flux Monitor in Simulation Coordinates")
plt.legend()
plt.show()

# %%
pml_layers = [mp.PML(1.0)]
resolution = 40

sim = mp.Simulation(cell_size=cell,
                    geometry=geometry,
                    sources=sources,
                    boundary_layers=pml_layers,
                    resolution=resolution)

# Store Ez snapshots
ez_data = []
def store_fields(sim):
    ez_data.append(sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez))

sim.run(mp.at_every(2, store_fields), until=100)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00402188 s
# Working in 2D dimensions.
# Computational cell is 44 x 17.975 x 0 with resolution 40
#      prism, center = (0.94981,6,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 84 vertices:
#           (20,6.982,0)
#           (19.996,6.982,0)
#           (19.996,6.195,0)
#           (17.996,6.51,0)
#           (17.581,6.51,0)
#           (17.581,6.852,0)
#           (17.647,6.982,0)
#           (17.344,6.982,0)
#           (17.411,6.852,0)
#           (17.411,6.51,0)
#           (16.996,6.51,0)
#           (14.996,6.195,0)
#           (8.33,6.195,0)
#           (6.33,6.51,0)
#           (5.915,6.51,0)
#           (5.915,6.852,0)
#           (5.981,6.982,0)
#           (5.678,6.982,0)
#           (5.745,6.852,0)
#           (5.745,6.51,0)
#           (5.33,6.51,0)
#           (3.33,6.195,0)
#           (-3.336,6.195,0)
#           (-5.336,6.51,0)
#           (-5.751,6.51,0)
#           (-5.751,6.852,0)
#           (-5.685,6.982,0)
#           (-5.988,6.982,0)
#           (-5.921,6.852,0)
#           (-5.921,6.51,0)
#           (-6.336,6.51,0)
#           (-8.336,6.195,0)
#           (-15,6.195,0)
#           (-17,6.51,0)
#           (-17.415,6.51,0)
#           (-17.415,6.852,0)
#           (-17.349,6.982,0)
#           (-17.652,6.982,0)
#           (-17.585,6.852,0)
#           (-17.585,6.51,0)
#           (-18,6.51,0)
#           (-20,6.195,0)
#           (-20,5.805,0)
#           (-18,5.49,0)
#           (-17.585,5.49,0)
#           (-17.585,5.148,0)
#           (-17.652,5.018,0)
#           (-17.349,5.018,0)
#           (-17.415,5.148,0)
#           (-17.415,5.49,0)
#           (-17,5.49,0)
#           (-15,5.805,0)
#           (-8.336,5.805,0)
#           (-6.336,5.49,0)
#           (-5.921,5.49,0)
#           (-5.921,5.148,0)
#           (-5.988,5.018,0)
#           (-5.685,5.018,0)
#           (-5.751,5.148,0)
#           (-5.751,5.49,0)
#           (-5.336,5.49,0)
#           (-3.336,5.805,0)
#           (3.33,5.805,0)
#           (5.33,5.49,0)
#           (5.745,5.49,0)
#           (5.745,5.148,0)
#           (5.678,5.018,0)
#           (5.981,5.018,0)
#           (5.915,5.148,0)
#           (5.915,5.49,0)
#           (6.33,5.49,0)
#           (8.33,5.805,0)
#           (14.996,5.805,0)
#           (16.996,5.49,0)
#           (17.411,5.49,0)
#           (17.411,5.148,0)
#           (17.344,5.018,0)
#           (17.647,5.018,0)
#           (17.581,5.148,0)
#           (17.581,5.49,0)
#           (17.996,5.49,0)
#           (19.996,5.805,0)
#           (19.996,5.018,0)
#           (20,5.018,0)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0.94981,-6,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 84 vertices:
#           (20,-5.018,0)
#           (19.996,-5.018,0)
#           (19.996,-5.805,0)
#           (17.996,-5.49,0)
#           (17.581,-5.49,0)
#           (17.581,-5.148,0)
#           (17.647,-5.018,0)
#           (17.344,-5.018,0)
#           (17.411,-5.148,0)
#           (17.411,-5.49,0)
#           (16.996,-5.49,0)
#           (14.996,-5.805,0)
#           (8.33,-5.805,0)
#           (6.33,-5.49,0)
#           (5.915,-5.49,0)
#           (5.915,-5.148,0)
#           (5.981,-5.018,0)
#           (5.678,-5.018,0)
#           (5.745,-5.148,0)
#           (5.745,-5.49,0)
#           (5.33,-5.49,0)
#           (3.33,-5.805,0)
#           (-3.336,-5.805,0)
#           (-5.336,-5.49,0)
#           (-5.751,-5.49,0)
#           (-5.751,-5.148,0)
#           (-5.685,-5.018,0)
#           (-5.988,-5.018,0)
#           (-5.921,-5.148,0)
#           (-5.921,-5.49,0)
#           (-6.336,-5.49,0)
#           (-8.336,-5.805,0)
#           (-15,-5.805,0)
#           (-17,-5.49,0)
#           (-17.415,-5.49,0)
#           (-17.415,-5.148,0)
#           (-17.349,-5.018,0)
#           (-17.652,-5.018,0)
#           (-17.585,-5.148,0)
#           (-17.585,-5.49,0)
#           (-18,-5.49,0)
#           (-20,-5.805,0)
#           (-20,-6.195,0)
#           (-18,-6.51,0)
#           (-17.585,-6.51,0)
#           (-17.585,-6.852,0)
#           (-17.652,-6.982,0)
#           (-17.349,-6.982,0)
#           (-17.415,-6.852,0)
#           (-17.415,-6.51,0)
#           (-17,-6.51,0)
#           (-15,-6.195,0)
#           (-8.336,-6.195,0)
#           (-6.336,-6.51,0)
#           (-5.921,-6.51,0)
#           (-5.921,-6.852,0)
#           (-5.988,-6.982,0)
#           (-5.685,-6.982,0)
#           (-5.751,-6.852,0)
#           (-5.751,-6.51,0)
#           (-5.336,-6.51,0)
#           (-3.336,-6.195,0)
#           (3.33,-6.195,0)
#           (5.33,-6.51,0)
#           (5.745,-6.51,0)
#           (5.745,-6.852,0)
#           (5.678,-6.982,0)
#           (5.981,-6.982,0)
#           (5.915,-6.852,0)
#           (5.915,-6.51,0)
#           (6.33,-6.51,0)
#           (8.33,-6.195,0)
#           (14.996,-6.195,0)
#           (16.996,-6.51,0)
#           (17.411,-6.51,0)
#           (17.411,-6.852,0)
#           (17.344,-6.982,0)
#           (17.647,-6.982,0)
#           (17.581,-6.852,0)
#           (17.581,-6.51,0)
#           (17.996,-6.51,0)
#           (19.996,-6.195,0)
#           (19.996,-6.982,0)
#           (20,-6.982,0)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (3.88578e-16,-1.04083e-15,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 64 vertices:
#           (3.5,-8.88178e-16,0)
#           (3.483,0.343,0)
#           (3.433,0.683,0)
#           (3.349,1.016,0)
#           (3.234,1.339,0)
#           (3.087,1.65,0)
#           (2.91,1.944,0)
#           (2.706,2.22,0)
#           (2.475,2.475,0)
#           (2.22,2.706,0)
#           (1.944,2.91,0)
#           (1.65,3.087,0)
#           (1.339,3.234,0)
#           (1.016,3.349,0)
#           (0.683,3.433,0)
#           (0.343,3.483,0)
#           (0,3.5,0)
#           (-0.343,3.483,0)
#           (-0.683,3.433,0)
#           (-1.016,3.349,0)
#           (-1.339,3.234,0)
#           (-1.65,3.087,0)
#           (-1.944,2.91,0)
#           (-2.22,2.706,0)
#           (-2.475,2.475,0)
#           (-2.706,2.22,0)
#           (-2.91,1.944,0)
#           (-3.087,1.65,0)
#           (-3.234,1.339,0)
#           (-3.349,1.016,0)
#           (-3.433,0.683,0)
#           (-3.483,0.343,0)
#           (-3.5,-8.88178e-16,0)
#           (-3.483,-0.343,0)
#           (-3.433,-0.683,0)
#           (-3.349,-1.016,0)
#           (-3.234,-1.339,0)
#           (-3.087,-1.65,0)
#           (-2.91,-1.944,0)
#           (-2.706,-2.22,0)
#           (-2.475,-2.475,0)
#           (-2.22,-2.706,0)
#           (-1.944,-2.91,0)
#           (-1.65,-3.087,0)
#           (-1.339,-3.234,0)
#           (-1.016,-3.349,0)
#           (-0.683,-3.433,0)
#           (-0.343,-3.483,0)
#           (0,-3.5,0)
#           (0.343,-3.483,0)
#           (0.683,-3.433,0)
#           (1.016,-3.349,0)
#           (1.339,-3.234,0)
#           (1.65,-3.087,0)
#           (1.944,-2.91,0)
#           (2.22,-2.706,0)
#           (2.475,-2.475,0)
#           (2.706,-2.22,0)
#           (2.91,-1.944,0)
#           (3.087,-1.65,0)
#           (3.234,-1.339,0)
#           (3.349,-1.016,0)
#           (3.433,-0.683,0)
#           (3.483,-0.343,0)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (3.88578e-16,-1.04083e-15,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 64 vertices:
#           (3.5,-8.88178e-16,0)
#           (3.483,0.343,0)
#           (3.433,0.683,0)
#           (3.349,1.016,0)
#           (3.234,1.339,0)
#           (3.087,1.65,0)
#           (2.91,1.944,0)
#           (2.706,2.22,0)
#           (2.475,2.475,0)
#           (2.22,2.706,0)
#           (1.944,2.91,0)
#           (1.65,3.087,0)
#           (1.339,3.234,0)
#           (1.016,3.349,0)
#           (0.683,3.433,0)
#           (0.343,3.483,0)
#           (0,3.5,0)
#           (-0.343,3.483,0)
#           (-0.683,3.433,0)
#           (-1.016,3.349,0)
#           (-1.339,3.234,0)
#           (-1.65,3.087,0)
#           (-1.944,2.91,0)
#           (-2.22,2.706,0)
#           (-2.475,2.475,0)
#           (-2.706,2.22,0)
#           (-2.91,1.944,0)
#           (-3.087,1.65,0)
#           (-3.234,1.339,0)
#           (-3.349,1.016,0)
#           (-3.433,0.683,0)
#           (-3.483,0.343,0)
#           (-3.5,-8.88178e-16,0)
#           (-3.483,-0.343,0)
#           (-3.433,-0.683,0)
#           (-3.349,-1.016,0)
#           (-3.234,-1.339,0)
#           (-3.087,-1.65,0)
#           (-2.91,-1.944,0)
#           (-2.706,-2.22,0)
#           (-2.475,-2.475,0)
#           (-2.22,-2.706,0)
#           (-1.944,-2.91,0)
#           (-1.65,-3.087,0)
#           (-1.339,-3.234,0)
#           (-1.016,-3.349,0)
#           (-0.683,-3.433,0)
#           (-0.343,-3.483,0)
#           (0,-3.5,0)
#           (0.343,-3.483,0)
#           (0.683,-3.433,0)
#           (1.016,-3.349,0)
#           (1.339,-3.234,0)
#           (1.65,-3.087,0)
#           (1.944,-2.91,0)
#           (2.22,-2.706,0)
#           (2.475,-2.475,0)
#           (2.706,-2.22,0)
#           (2.91,-1.944,0)
#           (3.087,-1.65,0)
#           (3.234,-1.339,0)
#           (3.349,-1.016,0)
#           (3.433,-0.683,0)
#           (3.483,-0.343,0)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 8.68174% done, 42.1994 s remaining
# subpixel-averaging is 14.6563% done, 23.466 s remaining
# subpixel-averaging is 21.0977% done, 15.0998 s remaining
# subpixel-averaging is 27.8191% done, 10.4008 s remaining
# subpixel-averaging is 34.6339% done, 7.57297 s remaining
# subpixel-averaging is 41.262% done, 5.70461 s remaining
# subpixel-averaging is 44.2493% done, 5.09424 s remaining
# subpixel-averaging is 47.5166% done, 4.46276 s remaining
# subpixel-averaging is 51.064% done, 3.86093 s remaining
# subpixel-averaging is 54.6115% done, 3.36965 s remaining
# subpixel-averaging is 57.7855% done, 2.95917 s remaining
# subpixel-averaging is 63.48% done, 2.31715 s remaining
# subpixel-averaging is 69.9214% done, 1.72877 s remaining
# subpixel-averaging is 76.8295% done, 1.21876 s remaining
# subpixel-averaging is 83.6443% done, 0.795075 s remaining
# subpixel-averaging is 90.9258% done, 0.404175 s remaining
# subpixel-averaging is 97.5539% done, 0.101945 s remaining
# subpixel-averaging is 9.33521% done, 38.984 s remaining
# subpixel-averaging is 16.5234% done, 20.33 s remaining
# subpixel-averaging is 25.3919% done, 11.8547 s remaining
# subpixel-averaging is 32.4868% done, 8.33493 s remaining
# subpixel-averaging is 38.9281% done, 6.29529 s remaining
# subpixel-averaging is 43.5958% done, 5.21009 s remaining
# subpixel-averaging is 47.4233% done, 4.51642 s remaining
# subpixel-averaging is 51.5308% done, 3.76875 s remaining
# subpixel-averaging is 55.2649% done, 3.24918 s remaining
# subpixel-averaging is 58.2522% done, 2.89032 s remaining
# subpixel-averaging is 65.1604% done, 2.15557 s remaining
# subpixel-averaging is 72.4419% done, 1.54083 s remaining
# subpixel-averaging is 80.937% done, 0.945947 s remaining
# subpixel-averaging is 87.8451% done, 0.564039 s remaining
# subpixel-averaging is 94.5666% done, 0.230158 s remaining
# subpixel-averaging is 9.61527% done, 37.7274 s remaining
# subpixel-averaging is 16.9902% done, 19.6991 s remaining
# subpixel-averaging is 23.8983% done, 12.9218 s remaining
# subpixel-averaging is 30.2463% done, 9.27321 s remaining
# subpixel-averaging is 36.6877% done, 6.91711 s remaining
# subpixel-averaging is 42.7556% done, 5.49769 s remaining
# subpixel-averaging is 46.303% done, 4.74788 s remaining
# subpixel-averaging is 50.0372% done, 4.02924 s remaining
# subpixel-averaging is 53.5846% done, 3.51439 s remaining
# subpixel-averaging is 56.7586% done, 3.06981 s remaining
# subpixel-averaging is 61.7063% done, 2.49146 s remaining
# subpixel-averaging is 68.8011% done, 1.82149 s remaining
# subpixel-averaging is 75.896% done, 1.27659 s remaining
# subpixel-averaging is 83.9243% done, 0.770199 s remaining
# subpixel-averaging is 92.1394% done, 0.343676 s remaining
# time for set_epsilon = 194.973 s
# -----------
# FloatProgress(value=0.0, description='0% done ')
# Meep progress: 2.7750000000000004/100.0 = 2.8% done in 4.0s, 140.6s to go
# on time step 222 (time=2.775), 0.0180234 s/step
# Meep progress: 5.675000000000001/100.0 = 5.7% done in 8.0s, 133.3s to go
# on time step 454 (time=5.675), 0.0172513 s/step
# Meep progress: 8.1875/100.0 = 8.2% done in 12.0s, 134.8s to go
# on time step 656 (time=8.2), 0.0198827 s/step
# Meep progress: 10.9625/100.0 = 11.0% done in 16.0s, 130.1s to go
# on time step 878 (time=10.975), 0.0180369 s/step
# Meep progress: 14.0/100.0 = 14.0% done in 20.1s, 123.4s to go
# on time step 1120 (time=14), 0.0167116 s/step
# Meep progress: 17.05/100.0 = 17.1% done in 24.1s, 117.2s to go
# on time step 1364 (time=17.05), 0.0164093 s/step
# Meep progress: 19.962500000000002/100.0 = 20.0% done in 28.1s, 112.6s to go
# on time step 1597 (time=19.9625), 0.0171758 s/step
# Meep progress: 22.762500000000003/100.0 = 22.8% done in 32.1s, 108.9s to go
# on time step 1821 (time=22.7625), 0.01788 s/step
# Meep progress: 25.6625/100.0 = 25.7% done in 36.1s, 104.6s to go
# on time step 2053 (time=25.6625), 0.017279 s/step
# Meep progress: 28.55/100.0 = 28.6% done in 40.1s, 100.4s to go
# on time step 2284 (time=28.55), 0.0173233 s/step
# Meep progress: 31.475/100.0 = 31.5% done in 44.1s, 96.0s to go
# on time step 2518 (time=31.475), 0.0170962 s/step
# Meep progress: 34.275/100.0 = 34.3% done in 48.1s, 92.3s to go
# on time step 2742 (time=34.275), 0.0179005 s/step
# Meep progress: 37.125/100.0 = 37.1% done in 52.1s, 88.3s to go
# on time step 2970 (time=37.125), 0.01762 s/step
# Meep progress: 40.0/100.0 = 40.0% done in 56.2s, 84.3s to go
# on time step 3200 (time=40), 0.0175574 s/step
# Meep progress: 42.962500000000006/100.0 = 43.0% done in 60.2s, 79.9s to go
# on time step 3437 (time=42.9625), 0.0169428 s/step
# Meep progress: 45.9125/100.0 = 45.9% done in 64.2s, 75.6s to go
# on time step 3673 (time=45.9125), 0.0170105 s/step
# Meep progress: 48.800000000000004/100.0 = 48.8% done in 68.2s, 71.6s to go
# on time step 3904 (time=48.8), 0.0173652 s/step
# Meep progress: 51.6625/100.0 = 51.7% done in 72.2s, 67.6s to go
# on time step 4133 (time=51.6625), 0.0174812 s/step
# Meep progress: 54.425000000000004/100.0 = 54.4% done in 76.2s, 63.8s to go
# on time step 4355 (time=54.4375), 0.018092 s/step
# Meep progress: 57.4375/100.0 = 57.4% done in 80.2s, 59.5s to go
# on time step 4596 (time=57.45), 0.016659 s/step
# Meep progress: 60.4375/100.0 = 60.4% done in 84.3s, 55.2s to go
# on time step 4836 (time=60.45), 0.0167167 s/step
# Meep progress: 63.362500000000004/100.0 = 63.4% done in 88.3s, 51.0s to go
# on time step 5070 (time=63.375), 0.0171075 s/step
# Meep progress: 66.2/100.0 = 66.2% done in 92.3s, 47.1s to go
# on time step 5297 (time=66.2125), 0.0176581 s/step
# Meep progress: 69.16250000000001/100.0 = 69.2% done in 96.3s, 42.9s to go
# on time step 5535 (time=69.1875), 0.0168783 s/step
# Meep progress: 72.1125/100.0 = 72.1% done in 100.3s, 38.8s to go
# on time step 5771 (time=72.1375), 0.0169673 s/step
# Meep progress: 75.10000000000001/100.0 = 75.1% done in 104.3s, 34.6s to go
# on time step 6011 (time=75.1375), 0.0167343 s/step
# Meep progress: 78.025/100.0 = 78.0% done in 108.3s, 30.5s to go
# on time step 6245 (time=78.0625), 0.0171319 s/step
# Meep progress: 80.95/100.0 = 81.0% done in 112.3s, 26.4s to go
# on time step 6478 (time=80.975), 0.0171711 s/step
# Meep progress: 83.91250000000001/100.0 = 83.9% done in 116.3s, 22.3s to go
# on time step 6716 (time=83.95), 0.0168558 s/step
# Meep progress: 86.72500000000001/100.0 = 86.7% done in 120.3s, 18.4s to go
# on time step 6941 (time=86.7625), 0.0178274 s/step
# Meep progress: 89.72500000000001/100.0 = 89.7% done in 124.3s, 14.2s to go
# on time step 7181 (time=89.7625), 0.0167112 s/step
# Meep progress: 92.61250000000001/100.0 = 92.6% done in 128.3s, 10.2s to go
# on time step 7412 (time=92.65), 0.0173238 s/step
# Meep progress: 95.5125/100.0 = 95.5% done in 132.3s, 6.2s to go
# on time step 7644 (time=95.55), 0.0172938 s/step
# Meep progress: 98.3125/100.0 = 98.3% done in 136.4s, 2.3s to go
# on time step 7868 (time=98.35), 0.0179216 s/step
# run 0 finished at t = 100.0 (8000 timesteps)

# %%
# Assume polygons, x_center, y_center, cell, source_x, source_y are already defined

# Get dielectric from MEEP
eps = sim.get_array(center=mp.Vector3(0,0),  # center at simulation origin
                    size=cell,
                    component=mp.Dielectric)

plt.figure(figsize=(6,6))

# Plot dielectric as background
plt.imshow(eps.T, cmap='Greys', origin='lower',
           extent=[-cell.x/2, cell.x/2, -cell.y/2, cell.y/2],
           alpha=0.7)

# Overlay polygons (shifted using centered coordinates)
for poly in polygons:
    shifted_poly = poly - np.array([x_center, y_center])
    plt.fill(shifted_poly[:,0], shifted_poly[:,1], facecolor='none',
             edgecolor='red', linewidth=1.5)

# Plot source
plt.plot(source_x, source_y, 'bx', markersize=10, label='Source')

# Plot flux monitor
flux_x = source_x + 39   # 39 µm downstream
flux_y = source_y
plt.plot(flux_x, flux_y, 'gx', markersize=10, label='Flux Monitor')

# Plot simulation cell boundary
plt.gca().add_patch(plt.Rectangle((-cell.x/2, -cell.y/2), cell.x, cell.y,
                                  fill=False, ls='--', edgecolor='black', linewidth=1))

plt.xlabel("x (µm)")
plt.ylabel("y (µm)")
plt.axis('equal')
plt.title("Dielectric + Polygon Overlay + Source")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

for i, field in enumerate(ez_data[::5]):  # plot every 5 steps
    plt.figure(figsize=(6,3))
    plt.imshow(np.rot90(field), cmap="RdBu", origin="lower")
    plt.colorbar(label="Ez field")
    plt.title(f"Snapshot {i}")
    plt.show()

# %%
plt.figure(figsize=(6,6))
for poly in polygons:
    shifted_poly = poly - np.array([origin_x, origin_y])
    plt.fill(shifted_poly[:,0], shifted_poly[:,1], alpha=0.3)
plt.plot(source_x_meep, source_y_meep, 'rx', markersize=10, label='Source')
plt.gca().add_patch(plt.Rectangle((0,0), cell.x, cell.y, fill=False, ls="--"))
plt.legend()
plt.show()

# %%
print("Cell size:", cell)
print("Cell center:", x_center, y_center)
print("Source relative:", source_x, source_y)
print("Polygon x range:", x_min, x_max)
print("Polygon y range:", y_min, y_max)
# Out:
# Cell size: Vector3<44.0, 17.964, 0.0>
# Cell center: 20.0 6.000000000000001
# Source relative: -20.0 5.999999999999999
# Polygon x range: 0.0 40.0
# Polygon y range: -0.982 12.982000000000001
